# %% [markdown]
# <div style="text-align: center; background-color: #0A6EBD; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#  Final Project Programming for Data Science
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #5A96E3; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Making questions</div>

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data from csv file

# %%
udemy_df = pd.read_csv("./Data/udemy.csv", parse_dates = ['published_time', 'last_update_date'])

# %%
udemy_df.head(10)
# Out:
#        id                                              title  is_paid   price  \
# 0  4715.0             Online Vegan Vegetarian Cooking School     True   24.99
# 1  1769.0         The Lean Startup Talk at Stanford E-Corner    False    0.00
# 2  5664.0  How To Become a Vegan, Vegetarian, or Flexitarian     True   19.99
# 3  7723.0                               How to Train a Puppy     True  199.99
# 4  8157.0                      Web Design from the Ground Up     True  159.99
# 5  8139.0           14-Day Yoga Detox and Empowerment Course     True   29.99
# 6  2762.0  Simple Strategy for Swing Trading the Stock Ma...     True   39.99
# 7  8082.0                     Ruby Programming for Beginners     True   74.99
# 8  8075.0  How to Create an Awesome Demo Video for Your B...     True  149.99
# 9  8069.0                                   Curso SEO Online     True   99.99
#
#                                             headline  num_subscribers  \
# 0  Learn to cook delicious vegan recipes. Filmed ...           2231.0
# 1  Debunking Myths of Entrepreneurship A startup ...          26474.0
# 2  Get the tools you need for a lifestyle change ...           1713.0
# 3  Train your puppy the right way with Dr. Ian Du...           4988.0
# 4  Learn web design online: Everything you need t...           1266.0
# 5  Lose weight, get healthier and fit on all leve...          20505.0
# 6  Use my favorite Technical Indicator and the Tr...           3309.0
# 7      Learn Ruby Programming the fast and easy way!          28824.0
# 8  You don't need to spend $10K in order to have ...          10761.0
# 9  Curso SEO práctico. Aprenda a posicionar su si...            483.0
#
#    avg_rating  num_reviews  num_comments  num_lectures  content_length_min  \
# 0     3.75000        134.0          42.0          37.0              1268.0
# 1     4.50000        709.0         112.0           9.0                88.0
# 2     4.40000         41.0          13.0          14.0                82.0
# 3     4.80000        395.0          88.0          36.0              1511.0
# 4     4.75000         38.0          12.0          38.0               569.0
# 5     4.53012        796.0         135.0          31.0              1163.0
# 6     3.85000        958.0         241.0           8.0                80.0
# 7     4.00000        741.0         189.0          56.0               363.0
# 8     3.90000        349.0         101.0          87.0               526.0
# 9     4.65000        100.0          45.0          73.0               373.0
#
#        published_time last_update_date              category  \
# 0 2010-08-05 22:06:13       2020-11-06             Lifestyle
# 1 2010-01-12 18:09:46              NaT              Business
# 2 2010-10-13 18:07:17       2019-10-09             Lifestyle
# 3 2011-06-20 20:08:38       2016-01-13             Lifestyle
# 4 2011-06-23 18:31:20              NaT                Design
# 5 2011-07-15 04:13:24       2018-05-22      Health & Fitness
# 6 2010-04-14 16:32:46       2019-03-07  Finance & Accounting
# 7 2011-07-08 21:32:55       2022-09-26           Development
# 8 2011-07-06 14:06:34       2020-11-22              Business
# 9 2012-07-03 17:03:28       2020-02-28             Marketing
#
#                   subcategory          topic language  \
# 0             Food & Beverage  Vegan Cooking  English
# 1            Entrepreneurship   Lean Startup  English
# 2             Other Lifestyle  Vegan Cooking  English
# 3         Pet Care & Training   Pet Training  English
# 4                  Web Design     Web Design  English
# 5                        Yoga           Yoga  English
# 6         Investing & Trading  Swing Trading  English
# 7       Programming Languages           Ruby  English
# 8                       Media     Demo Video  English
# 9  Search Engine Optimization            SEO  Spanish
#
#                                           course_url    instructor_name  \
# 0           /course/vegan-vegetarian-cooking-school/        Angela Poch
# 1  /course/the-lean-startup-debunking-myths-of-en...          Eric Ries
# 2  /course/see-my-personal-motivation-for-becomin...        Angela Poch
# 3                /course/complete-dunbar-collection/         Ian Dunbar
# 4             /course/web-design-from-the-ground-up/     E Learning Lab
# 5  /course/yoga-for-weight-loss-and-core-strength...      Sadie Nardini
# 6            /course/swing-trading-the-stock-market/         Tom Watson
# 7  /course/learn-ruby-programming-in-ten-easy-steps/  Huw Collingbourne
# 8         /course/how-to-create-awesome-demo-videos/   Miguel Hernandez
# 9  /course/curso-de-posicionamiento-en-buscadores...    Juan Jose Ramos
#
#             instructor_url
# 0        /user/angelapoch/
# 1          /user/ericries/
# 2        /user/angelapoch/
# 3        /user/ian-dunbar/
# 4       /user/edwin-ang-2/
# 5      /user/sadienardini/
# 6         /user/tomwatson/
# 7  /user/huwcollingbourne/
# 8   /user/miguelhernandez/
# 9      /user/juanjo-ramos/

# %% [markdown]
# ## Making questions

# %% [markdown]
# ### Question 1:

# %% [markdown]
# Benefits of finding the answer?

# %% [markdown]
# Analyze data to answer the question?

# %%
udemy_df['year'] = udemy_df['published_time'].dt.year
average_duration_per_year = udemy_df.groupby('year')['content_length_min'].mean()
print(average_duration_per_year)
# Out:
# year
# 2010    379.500000
# 2011    610.473684
# 2012    406.974138
# 2013    313.129359
# 2014    245.506169
# 2015    245.273162
# 2016    270.531787
# 2017    292.292870
# 2018    314.003970
# 2019    310.210421
# 2020    260.617196
# 2021    243.627223
# 2022    237.158537
# Name: content_length_min, dtype: float64

# %%
plt.figure(figsize=(10, 6))
average_duration_per_year.plot(kind='bar', color='skyblue')
plt.title('Thời Gian Trung Bình Của Khóa Học Mỗi Năm')
plt.xlabel('Năm')
plt.ylabel('Thời Gian Trung Bình')
plt.show()

# %% [markdown]
# ### Question 2: The diversity and scaling of languages ​​over time

# %% [markdown]
# Benefits of finding the answer?
#
# It helps us see the situation about the diversity and proportion of languages ​​used in udemy courses. This can also help us predict which languages ​​will be commonly used in the near future

# %% [markdown]
# Analyze data to answer the question?

# %%
language_per_year = udemy_df.groupby('year')['language'].unique()
language_per_year = language_per_year.apply(lambda x: len(x))

# %%
plt.figure(figsize=(10, 6))
language_per_year.plot(kind='bar', color='skyblue')
plt.title('Number of languge over year')
plt.xlabel('Year')
plt.ylabel('Number language')
plt.show()

# %% [markdown]
# We see languages ​​diversify over time, with more and more types of languages ​​serving learner.s

# %% [markdown]
# Because there are a lot of language, so we take 5 top most popular language, another language we put it type 'Other'

# %%
list_language_top = udemy_df.groupby('language')['id'].count().nlargest(5).index
list_language_top = pd.Series(list_language_top)
language_top = udemy_df[udemy_df['language'].isin(list_language_top)]
df_language = language_top.groupby(['year', 'language']).size().unstack(fill_value=0)
df_language['Other'] = udemy_df.groupby('year')['language'].size()- df_language.sum(axis=1)
df_percentage_language = df_grouped.div(df_language.sum(axis=1), axis=0) * 100
df_percentage_language.plot(kind='area', stacked=True, title='Ratio between languages over years')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
fig = plt.gcf()
fig.set_size_inches(10, 5)
plt.show()

# %% [markdown]
# We can see the trend of using languages ​​such as 'Spanish', 'Postuguese', ... is increasing.
#
# English accounts for a large proportion but is no longer as dominant as before
